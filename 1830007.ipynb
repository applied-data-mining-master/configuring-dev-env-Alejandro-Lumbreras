# %%
import numpy as np
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# %matplotlib inline

arr = np.random.randint(-100, 101,(2,1000))


plt.scatter(arr[0], arr[1])
plt.show()
